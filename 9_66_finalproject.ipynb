# %%
import csv 
import random
from random import choice

import nltk
from nltk.util import ngrams
from nltk.probability import *
import numpy as np

from collections import Counter

# %%
# MAKE SURE YOU UPLOAD THE CORRECT FILES SO THAT COLAB CAN USE IT (see sidebar)
# training_sentences.csv
# cmu_in_childes_small.csv
# testing_sentences.csv

# %%
# DIANA'S ORIGINAL CODE 

def trigrams_in_sent(sent):
    return [ngram for ngram in ngrams(sent, 3, pad_left=True, pad_right=True)]

def all_trigrams(sents):
    return [ngram for sent in sents for ngram in ngrams(sent, 3, pad_left=True, pad_right=True)]

def trigram_freq_dist(all_trigrams):
    return nltk.FreqDist(all_trigrams)

def kneser_ney_prob_dist(sents):
    trigram_list = all_trigrams(sents)
    fd = trigram_freq_dist(trigram_list)
    return KneserNeyProbDist(fd)

def kneser_ney_prob(trigram, kn_prob_dist):
    return kn_prob_dist.prob(trigram)

def process_word(word):
    new_word = word
    new_word = new_word.replace('[', '')
    new_word = new_word.replace(']', '')
    new_word = new_word.replace("'", "")
    new_word = new_word.replace(' ', '')
    new_word = new_word.replace('"', '')
    new_word = new_word.lower()
    return new_word

def create_kneser_ney_prob_dist():
    sents_for_dist = []
    with open ('training_sentences.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=",")
        line_count = 0
        for row in csv_reader:
            if line_count != 0:
                sent = row[29]
                split_sent = sent.split(",")
                split_sent_list = []
                for word in split_sent:
                    processed_word = process_word(word)
                    split_sent_list.append(processed_word)
                sents_for_dist.append(split_sent_list)
            line_count += 1
    return kneser_ney_prob_dist(sents_for_dist)

def create_english_cmu_dict():
    english_cmu_dict = {}
    with open ('cmu_in_childes_small.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=",")
        line_count = 0
        for row in csv_reader:
            if line_count != 0:
                english_cmu_dict[row[1]] = [row[8],row[10],row[11],row[12],row[13],row[14],row[15]]
            line_count += 1
    return english_cmu_dict

def create_english_words(english_dict):
    return list(english_dict.keys())

def init_random_sentence(english_words, num_words):
    sent = []
    for i in range(num_words):
        new_word_ind = random.randint(0, len(english_words)-1)
        new_word = english_words[new_word_ind]
        sent.append(new_word)
    return sent

def perturb_sentence(english_words, sent):
    new_sent = sent.copy()
    num_words = len(sent)
    change_ind = random.randint(0, num_words-1)
    new_word_ind = random.randint(0, len(english_words)-1)
    new_word = english_words[new_word_ind]
    new_sent[change_ind] = new_word
    return new_sent

def english_to_ipa(english_dict, sent):
    all_ipa_sent=[]
    for i in range(7):
      ipa_sent = []
      for word in sent:
          ipa_sent.append(english_dict[word][i])
      all_ipa_sent.append(ipa_sent)
    return all_ipa_sent

def trigram_prior_for_sent(sent, kn_prob_dist):
    trigrams = trigrams_in_sent(sent)
    num_trigrams = len(trigrams)
    trigram_priors = np.zeros(num_trigrams)
    for i in range(num_trigrams):
        trigram_priors[i] = kneser_ney_prob(trigrams[i], kn_prob_dist)
    return np.prod(trigram_priors)

def calculate_likelihood(guess, actual, match_multiplier=0.99):
    matches = 0
    no_matches = 0
    for i in range(len(actual)):
        found_match = False
        for x in range(7):
          if guess[x][i] == actual[i] and not found_match:
              matches += 1
              found_match = True
        else:
            no_matches += 1
    no_match_multiplier = 1-match_multiplier
    likelihood = (match_multiplier**matches)*(no_match_multiplier**no_matches)
    return likelihood

def calculate_prob(english_dict, kn_prob_dist, guess, actual, match_multiplier=0.99):
    guess_ipa = english_to_ipa(english_dict, guess)
    return trigram_prior_for_sent(guess, kn_prob_dist)*calculate_likelihood(guess_ipa, actual, match_multiplier) + 0.00001

def find_n_most_common_transcriptions(n, plausible_transcriptions):
    new_list = []
    for transcription in plausible_transcriptions:
        new_list.append(' '.join(transcription))
    counter = Counter(new_list)
    common_list = counter.most_common(n)
    print(common_list)
    return common_list

def transcribe(actual):
    plausible_transcriptions = []
    num_words = len(actual)
    english_dict = create_english_cmu_dict()
    english_words = create_english_words(english_dict)
    kn_prob_dist = create_kneser_ney_prob_dist()
    old_guess = init_random_sentence(english_words, num_words)
    for i in range(500000):
        new_guess = perturb_sentence(english_words, old_guess)
        old_guess_prob = calculate_prob(english_dict, kn_prob_dist, old_guess, actual)
        new_guess_prob = calculate_prob(english_dict, kn_prob_dist, new_guess, actual)
        if new_guess_prob/old_guess_prob > random.random():
            old_guess = new_guess
        plausible_transcriptions.append(old_guess)
    return find_n_most_common_transcriptions(10, plausible_transcriptions)

def get_all_transcriptions():
    all_transcriptions = []
    with open ('test_sentences.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=",")
        line_count = 0
        for row in csv_reader:
            if line_count != 0:
                sent = row[29]
                split_sent = sent.split(",")
                split_sent_list = []
                for word in split_sent:
                    processed_word = process_word(word)
                    split_sent_list.append(processed_word)
                all_transcriptions.append(split_sent_list)
            line_count += 1
    return all_transcriptions

# %%
#transcribe(['mɑmi'])
#transcribe(['pɑp', 'pɑp', 'pɑp', 'pɑp', 'pɑp'])
#transcribe(['wəts', 'ðɪs', 'fɔɹ'])
#transcribe(['oʊ'])
transcribe(['θæŋk', 'ju'])
# Out:
# [('digging plate', 4), ('name drinking', 3), ("cow's gail", 3), ('aislinn were', 3), ("nothing's bet", 3), ('inside fox', 3), ('to love', 3), ('meal card', 3), ('choke peeping', 3), ('carry paws', 3)]

# %%
import pandas as pd
df = pd.read_csv('testing_sentences.csv')
new = df.copy()

# %%
def get_mcmc_translation(ipa):
  ipa_split = ipa.split(" ")
  transcription = transcribe(ipa_split)[0][0]
  print(transcription)
  return transcription

new['mcmc sentences'] = new["adjusted_model_phonology"].apply(lambda x: get_mcmc_translation(x))
# Out:
# [('knives henry', 4), ('eaten dolly', 3), ('pole drives', 3), ('loft especially', 3), ('knows err', 3), ('girl filling', 3), ('messed light', 3), ('thomas vase', 3), ('ears rocket', 3), ('groceries hens', 3)]
# knives henry
# [('wife jen', 3), ('punch themselves', 3), ('night sandwiches', 3), ('choo shell', 3), ('nah nobody', 3), ('he able', 3), ('cheat bottles', 3), ('otter skating', 3), ('spray enough', 3), ('shaped toot', 3)]
# wife jen
# [('love doodle wanted hoop police', 2), ('program parade curious dining peep', 2), ('clap scared door nine builder', 2), ("smells robin junk children's crisp", 2), ('buy millions horses caravan castle', 2), ('up kim eyes nicer american', 2), ('donald pole rice calf outfit', 2), ('donna neighbor rest pickles fingers', 2), ('dinosaurs spilt stir patrick diamond', 2), ('neck bib soldiers oy lock', 2)]
# love doodle wanted hoop police
# [('build basket comes', 2), ('tuck candy smelly', 2), ('fix wicked danny', 2), ('brushes nail magnet', 2), ('doughnut unless know', 2), ('win worm play', 2), ('kneeling undo luck', 2), ('hose violin year', 2), ('bedroom garbage faces', 2), ('package furniture guitar', 2)]
# build basket comes
# [("cat's dragon", 4), ("i'll president", 4), ('thingy rope', 4), ('spread player', 4), ('pluto outfit', 3), ('rocking boot', 3), ('trumpet chasing', 3), ('toys leaf', 3), ('colored burned', 3), ('recognizes mother', 3)]
# cat's dragon
# [("sam's matching", 4), ('hand minnie', 3), ('doh end', 3), ('dr porcupine', 3), ('cause den', 3), ('kill zero', 3), ('ballet breathe', 3), ('waking blows', 3), ('chew let', 3), ('fantastic peg', 3)]
# sam's matching
# [('hon else behind plastic', 2), ('apple spanking remembered allowed', 2), ("controller thrown what's otter", 2), ('plays richard candles rattle', 2), ('dan them swings older', 2), ('sofa grab hi jumped', 2), ('easier plastic rubbing squirt', 2), ('eater figured o cute', 2), ('means deliver thin bead', 2), ('tooth spencer coal lord', 2)]
# hon else behind plastic
# [('hickory stories coco scared movies', 2), ('swims bored down pattern thursday', 2), ('knives pajamas jeans comfy mrs', 2), ('p bucket van playground lemon', 2), ('crabs lie boys recognize getting', 2), ('winnie bo tricky address mobile', 2), ('ugly time tie paints she', 2), ('pile babe alive n artist', 2), ('ninety pull kangaroo outfit upside', 2), ('geese plays hooray buy ribbit', 2)]
# hickory stories coco scared movies
# [('drink hoops asked', 2), ('breaks lisa closed', 2), ('hula exciting august', 2), ('idea raspberries tin', 2), ('wearing melon vinegar', 2), ('meat vegetables least', 2), ('net forward saw', 2), ('cuts smells sentence', 2), ('difference sold fingernails', 2), ('teething pens eagle', 2)]
# drink hoops asked
# [('cheers snail', 3), ('village toe', 3), ('wrapping li', 3), ('peacock girl', 3), ('cross yelling', 3), ('aaron pointing', 3), ('dripping oops', 3), ('william minutes', 3), ("sister's ride", 3), ('shoulder bill', 3)]
# cheers snail
# [('spain sweetheart', 4), ('spoil beds', 3), ('daniel problem', 3), ('plums up', 3), ('sack mess', 3), ('wight butter', 3), ('jess munch', 3), ('warm moneys', 3), ('needed heat', 3), ('sting pass', 3)]
# spain sweetheart
# [("giraffes quack how's cupboard guess junk boats was doctor throw ye february julie engines easier ants", 2), ("myself poppy zebras else's much soft tub doll's fruit lord back trousers james french dae suddenly", 2), ('aid laugh tights lookit slowly enjoying busy paddling hooray moneys hiding grab kissing puts mash err', 2), ("hungry potatoes hours riding starfish squeaky pickles somebody's found journey bridge pair ramp bangs lane i'm", 2), ('tires cooker anyway shining robbie fred deedee chased interesting morning lovely yogurt electric nancy grandad doctors', 2), ("furniture scribble till snort waving customer brother's trumpet lonely patrick blueberry put kids gee naomi laughed", 2), ('across louder wire hiding leaving stem thick pies dresses whoop rattle like brothers closer sore frame', 2), ("macdonald whiskers dun except tread being poo gown bin recording snow nickel everyone ups we'll completely", 2), ("most wouldn't we're sort sucking jo purple fred seemed frogs snip tank purdie cheeky enjoying dinner", 2), ('we healthy phone ruler yay horse trapped mouth went ernie dishes trumpet spiderman applesauce potter pulling', 2)]
# giraffes quack how's cupboard guess junk boats was doctor throw ye february julie engines easier ants
# [("broke break gail's", 2), ("teddy's attack signs", 2), ('mittens eater figured', 2), ('law dryer wrong', 2), ('spencer daisy snapped', 2), ('mines pinched zoe', 2), ('anyone room nothing', 2), ('down pictures picnic', 2), ("pay buildings pig's", 2), ('vitamin fifteen moving', 2)]
# broke break gail's
# [('magazine mayonnaise', 4), ('behind scotland', 3), ('brother went', 3), ("where's numbers", 3), ('enjoyed record', 3), ('mariana outfit', 3), ('tank clever', 3), ('lip steak', 3), ('kelly chug', 3), ('cricket et', 3)]
# magazine mayonnaise
# [('test aislinn university butcher almost actually', 2), ("swims grandma's roy cab chased duck", 2), ("baby's it's corn flavor di spare", 2), ('pond married shovel cousins tights points', 2), ('michael dalmatian pippin sheep sofa saturday', 2), ('giving covered date microphone nineteen jones', 2), ('paddington asleep centre foot snowy tag', 2), ("bun themselves nobody's photos plaster coat", 2), ('february less snack paint open brooklyn', 2), ('large yeh army sleeping eating och', 2)]
# test aislinn university butcher almost actually
# [('pops sweets ladybird drink', 2), ('bats bunnies painted wa', 2), ('imagine lay shoulder teeny', 2), ('carry gonna oatmeal rolly', 2), ('passengers lets war return', 2), ('straw dock boring forest', 2), ('neither falling wheelbarrow whenever', 2), ('err broom years mistake', 2), ('sharks baby gobble swinging', 2), ('duck fingernails sides gate', 2)]
# pops sweets ladybird drink
# [('ryan lit dumper', 2), ('soda blueberry touch', 2), ('photos buckle someday', 2), ('yet listen tomato', 2), ('helping much chew', 2), ("type behind he'll", 2), ("bib they'd capital", 2), ('grandmother ark proper', 2), ('big collar hats', 2), ('thankyou tricks wrap', 2)]
# ryan lit dumper
# [("noah girl's", 4), ('sent without', 3), ('graeme washer', 3), ('break marmalade', 3), ('robot tool', 3), ("track name's", 3), ('travis drag', 3), ('gift doors', 3), ('reads bigger', 3), ('hurray starting', 3)]
# noah girl's
# [('forgot lessons wight african cane', 2), ('cheerleader faces spots observer doughnuts', 2), ('poorly quack needs black gun', 2), ('poorly quack needs black wiped', 2), ('tongue dryer of load messing', 2), ('dentist lids peppers again sweets', 2), ('hunt igloo es trouble ostrich', 2), ('cardigan crocodiles back glue hers', 2), ('cardigan crocodiles worm glue soap', 2), ('roared market club lolly curls', 2)]
# forgot lessons wight african cane
# [("granola several number's finding amount course", 2), ('helping regular fairly en loved pussy', 2), ('alligators heat spanish suitcase seventeen tear', 2), ('rock lip otter patient sometimes say', 2), ('flavor whoops fourteen laugh melon carrot', 2), ('send yay chi arrow copy dinosaur', 2), ('makes carefully mama notes tired normal', 2), ('stripes chalk lake daddies stupid somehow', 2), ('spitting loft benjamin giraffes thanks gingerbread', 2), ("knew stepping poor gingerbread celery sarah's", 2)]
# granola several number's finding amount course
# [("piles squashing for horse's", 2), ('dusting chasing must too', 2), ('catherine asian diamond mistake', 2), ('field fourth walk fighting', 2), ('called still waffle sixty', 2), ('birds flour bambi comb', 2), ("grandma's idea bumper signs", 2), ('pay fairy mo buckle', 2), ('cool flowers banjo bare', 2), ('absolutely buildings nicely anyways', 2)]
# piles squashing for horse's
# [('question fred space', 2), ('bunny envelope brown', 2), ("where're et dah", 2), ('iron followed moves', 2), ('turning hat cricket', 2), ('doctors basket isabel', 2), ("that'd incredible fraser's", 2), ('york wait cost', 2), ('custard hint tight', 2), ("vinegar here's steam", 2)]
# question fred space
# [("comfortable daddy's", 4), ('weather smiling', 4), ('dancer carrot', 4), ('recognize cricket', 3), ('wondering lips', 3), ("mum's something's", 3), ('care swan', 3), ('covered tickles', 3), ('cow chest', 3), ('english vacation', 3)]
# comfortable daddy's
# [("biscuits cries head's", 2), ('gym pumpkins choo', 2), ('singing cookie mushroom', 2), ('balloon boss touched', 2), ('october loft problem', 2), ('ground locked favorite', 2), ('munch reach tub', 2), ('rolling mix hide', 2), ('museum plums those', 2), ('suck seeing spilling', 2)]
# biscuits cries head's
# [('messed hold', 4), ('good cross', 3), ("she'd asked", 3), ('spot tip', 3), ('need margaret', 3), ('donkey something', 3), ('meeting y', 3), ('bumpy lemons', 3), ('mane danger', 3), ('cracked scoop', 3)]
# messed hold
# [("crown owe number's dalmatian", 2), ('kind hulk snakes ended', 2), ('exciting moon oop slot', 2), ('toaster tent hard kitten', 2), ('neat choo confused down', 2), ('pancakes choose who stomach', 2), ('melon x chug stick', 2), ('picture mothers alive sounded', 2), ('pond chips bell dey', 2), ('hundred postman tights watch', 2)]
# crown owe number's dalmatian
# [('forest creatures', 4), ('music joe', 3), ('macdonald hope', 3), ('bah hung', 3), ('married steve', 3), ("badge mcdonald's", 3), ('shade odd', 3), ('becky mask', 3), ('purse burger', 3), ('crying greens', 3)]
# forest creatures
# [('curious storm bin friends peoples lay ty okay rubbing', 2), ('piles soap pulled tins dingo patty bet pulled merrily', 2), ("gary hannah lion's sonia jungle bonk chicks fluff hurts", 2), ('remembered dropping spitting vacation ballerina bottom recently towards vacuum', 2), ("i eleanor goggins tripped cob baker's jim mark fill", 2), ('bikes actually not fireman scared pile raccoon woods quack', 2), ("good it'd hand chance mummy's after aah pencil pushes", 2), ("skunks seemed lawn regular possibly tell spot baker's joke", 2), ("thrown baker's sleep cough pretzel son roy passenger fresh", 2), ('twist icing past margarine hee power whisper jake rude', 2)]
# curious storm bin friends peoples lay ty okay rubbing
# [('usual grumpy', 3), ('full easily', 3), ('saying rub', 3), ('sleeve stay', 3), ('hamburgers honk', 3), ("we'd wine", 3), ('coat queen', 3), ('understand climbing', 3), ('hamster freezing', 3), ('hippopotamus breaks', 3)]
# usual grumpy
# [('jimmy hopping', 4), ('sense buy', 3), ('foods nearer', 3), ('drops bottom', 3), ('napkins dinner', 3), ('sharing whole', 3), ('crumbs andrew', 3), ("engine's behind", 3), ('show poo', 3), ('thirsty poodle', 3)]
# jimmy hopping
# [('jumped hospital crib pub copying squashed', 2), ("yourself tinker she'd inside evening bubble", 2), ('mister decorate high platform mary dokey', 2), ('i uh theo pens american artist', 2), ('today lap laurie television shell met', 2), ('rob rake counter whispering cage bothering', 2), ("build when's shell melissa touch cherry", 2), ("jello say don't wood problems middle", 2), ('dinosaurs farm dada soon back downstairs', 2), ('lawn witch cha wrong tasty fault', 2)]
# jumped hospital crib pub copying squashed
# [('doggy lose pretzels', 2), ("shouldn't try spaceship", 2), ('jumps pear cuddly', 2), ('nasty smile puss', 2), ('were panda scarecrow', 2), ('seventeen parcel choo', 2), ('car wanted pillows', 2), ('journey norman squeaky', 2), ('skate picks fee', 2), ('walk tights chance', 2)]
# doggy lose pretzels
# [('package played cries tom', 2), ('boom nancy about point', 2), ("gonna door's eight vehicle", 2), ('sidewalk cocoa plums mop', 2), ('sausage stole pillow granola', 2), ('easter hamburgers throw banana', 2), ('capital di lorry fairly', 2), ('sword sorted cream dream', 2), ("field doll's pipe sandals", 2), ('climb toilet shout lady', 2)]
# package played cries tom
# [('some female flags', 2), ('asking interested sausages', 2), ('painting during toilet', 2), ('followed rhino real', 2), ('stack leopard question', 2), ('hall molly drawers', 2), ('swish log whale', 2), ("pips hadn't miss", 2), ('sandbox movies other', 2), ('needs float cupcakes', 2)]
# some female flags
# [("caroline's moved", 4), ('clock tissue', 4), ('chair lips', 4), ('talking messy', 3), ('little squeeze', 3), ('fingers bat', 3), ("she'd wagon", 3), ('anywhere miriam', 3), ('against georgie', 3), ('dinner break', 3)]
# caroline's moved
# [('buzzy frogs', 4), ('colored octopus', 3), ('yay bees', 3), ('ah seat', 3), ('michelle stepping', 3), ('running dummy', 3), ('airplanes people', 3), ('goggins course', 3), ('diaper kill', 3), ('roof sell', 3)]
# buzzy frogs
# [('still moment', 3), ('yup slippers', 3), ('stove dish', 3), ('pest seen', 3), ('goofy part', 3), ('washer belly', 3), ('site being', 3), ('trees dancer', 3), ('donkey abigail', 3), ('x freezer', 3)]
# still moment
# [('towards ne', 4), ('morning grace', 4), ("muffins where're", 3), ('alone bin', 3), ('bother instead', 3), ('sniffing landing', 3), ('sour plain', 3), ('dub dripping', 3), ('painting sounds', 3), ('enjoyed racing', 3)]
# towards ne
# [('woody pox', 4), ('dee wears', 3), ('carrier halloween', 3), ('microwave doctors', 3), ('x drive', 3), ('gates brushes', 3), ('peeping gift', 3), ('horses lorry', 3), ('wiggle since', 3), ('cars hotel', 3)]
# woody pox
# [('lessons faster out choo cabbage', 2), ('men telling nicola chicken whatever', 2), ('seventy cousins fallen bottle keeper', 2), ("i'll really mask helped hard", 2), ("igloo hon tired fries monkey's", 2), ('mushroom engines giant die temperature', 2), ('fourteen mushroom holes shout tomatoes', 2), ('piano doctor onto bang decorations', 2), ('beaver door steady pennies had', 2), ('roy really thumb dumb sa', 2)]
# lessons faster out choo cabbage
# [('crazy blue tail', 2), ("where's lofty mine", 2), ('saturday jonathan from', 2), ('candles lambs unless', 2), ('bracelet nom shark', 2), ("yeah swallowed where'd", 2), ('opened drink can', 2), ('cones lips spray', 2), ('sheet below holes', 2), ('suck vacation thirty', 2)]
# crazy blue tail
# [('sonia bill meg', 2), ('purse ways gold', 2), ('ye soil these', 2), ("cock ring name's", 2), ('mask err nicola', 2), ("water's guy's thanks", 2), ('jason blueberries especially', 2), ('mommies lesson killed', 2), ('hung sailboat tony', 2), ('roman buildings beaver', 2)]
# sonia bill meg
# [('black after watermelon drums comfy', 2), ('coffee puzzle diggers rectangle sliding', 2), ("who's she pumpkins hidden feel", 2), ('hamburgers pillows fireman movies wreck', 2), ('rid crust staying pretzel seeing', 2), ('coins friends beating caterpillars duckies', 2), ('lives loose pull just flag', 2), ('steve cans noses willie engine', 2), ("waffles bumpy olivia that'd tv", 2), ('kipper boxes thrown pot machine', 2)]
# black after watermelon drums comfy
# [('rolls silly caravan hurrah splinter', 2), ('class ouch melon steven bar', 2), ('worried lemme grade comfy suit', 2), ('dalmatian moment emma un record', 2), ('stars fifteen fries bookcase weather', 2), ('tear alone garage mickey darth', 2), ('slip rid boats hat postman', 2), ('towel mobile doll cartoons page', 2), ('net cobra pipe door drawers', 2), ('checking sam tied yarn bertie', 2)]
# rolls silly caravan hurrah splinter
# [('melted paul sting', 2), ('toad blackpool for', 2), ('puff nobody telling', 2), ('dominic ears scare', 2), ('squares money joe', 2), ('alley den bottle', 2), ("bothered panties boy's", 2), ('bouncing cone lambs', 2), ('figure kent paws', 2), ("people's frozen crunching", 2)]
# melted paul sting
# [('blocks ram slipped', 2), ('carl chance missing', 2), ('slipper strong tins', 2), ('gorilla blah jumps', 2), ('unusual heart better', 2), ('thread kicking whatever', 2), ('minnie rules n', 2), ("ay else's interest", 2), ('mood eagle owls', 2), ('quack happy pat', 2)]
# blocks ram slipped
# [('late buns picture ladies waking', 2), ("mark's picked pen snack gotcha", 2), ('sounds chewing at mia dolphins', 2), ('rhyme dat lose pull witches', 2), ("knitting pack label laid there'll", 2), ('begin picked telephone y wight', 2), ("cow's sold record policeman dish", 2), ('vegetable lunch hens chops dry', 2), ('football reminds christopher sailboat fake', 2), ('ruth juice grade fell season', 2)]
# late buns picture ladies waking
# [('dot whistle book', 2), ('follow tapes sweetheart', 2), ("drivers knees grandad's", 2), ('honey words bin', 2), ('guns macaroni machines', 2), ('carpet guy plastic', 2), ('loved plays dirty', 2), ('match bell chris', 2), ('wasp slide das', 2), ('scrambled apples roman', 2)]
# dot whistle book
# [('snail chimney speak witch doughnuts', 2), ('care elevator ladybugs anyway cleaned', 2), ('cool york tinker cheerios rolly', 2), ('erin hate cuddle giddy pineapple', 2), ("basketball they've feel loved grownups", 2), ('tinker card stroller those sold', 2), ('jerry man candle nope real', 2), ("chi's foot band vroom safe", 2), ('ted eleven grab bricks bugs', 2), ('stole vehicle carries anyways building', 2)]
# snail chimney speak witch doughnuts
# [("there'll apparently", 3), ('practice strong', 3), ('soldier done', 3), ('annie closer', 3), ('gold balloons', 3), ("parts why're", 3), ('dreamed lose', 3), ('b hand', 3), ('granddad reaching', 3), ('afraid proper', 3)]
# there'll apparently
# [("ruth linda's lick cottage hoop pass working friday", 2), ('puddle martin sorts somebody higher ling builder chip', 2), ('needed himself annie father uncle cone hafta headache', 2), ('ladybug rides cloud tommy dangerous uses cartoon triceratops', 2), ('goldilocks shoes colin dis river anyone spots bumpy', 2), ("gail's what's bash mice stable jobs downstairs et", 2), ('smith envelopes clap bucket field wall florida odd', 2), ('measuring patty beads calling buckle sharks squeak powder', 2), ('drag ripped bethany playing liked rhyme measure flags', 2), ("bobo jumping kept zoe ladybugs bum being number's", 2)]
# ruth linda's lick cottage hoop pass working friday
# [('job rides', 4), ("mama's diesel", 4), ('snacks biscuit', 3), ('bugs tummy', 3), ('names naughty', 3), ("party dad's", 3), ('runs gang', 3), ('toaster lookit', 3), ('machine es', 3), ('spilled paid', 3)]
# job rides
# [('master plan shirt london slip spaceship', 2), ('dessert closed sewing hamburger run paying', 2), ("hopefully dragons tickle person foot grandma's", 2), ('spencer teach expensive spilling eating picks', 2), ("somewhere lady's cindy paying honestly mail", 2), ('written surfing strong surprise yellow tip', 2), ('wagon both vehicles screaming graham special', 2), ('sled thinking lazy pan smile ago', 2), ("flakes we'd brush zip else daddies", 2), ('beard grapefruit crane slowly seek kittens', 2)]
# master plan shirt london slip spaceship
# [('greens ne', 4), ('investigator weasel', 3), ('for paw', 3), ('colorful biting', 3), ('porch tacos', 3), ('de tigers', 3), ("takes doesn't", 3), ('charlotte henry', 3), ('tim told', 3), ('won our', 3)]
# greens ne
# [('rhyme yah damn', 2), ('short yo gasped', 2), ('banana come hugging', 2), ("sheeps adam's diapers", 2), ("wind weren't ca", 2), ('phones nobody bun', 2), ('goodness lassie squash', 2), ('chased wight which', 2), ('taller counting stuffed', 2), ('castle ever buzz', 2)]
# rhyme yah damn
# [('breathe henry phones jimmy poppy', 2), ('bad cha popcorn spade shoe', 2), ('cows windy tub fridge dressed', 2), ('juicy matter serious everything emily', 2), ('drawer beside careful mothers poor', 2), ('make factory oops records knew', 2), ('think fly louise colin auntie', 2), ('drivers spill hurry peacock wheel', 2), ("towards beep henry's edge couldn't", 2), ('spare bossy meeting falls kim', 2)]
# breathe henry phones jimmy poppy
# [('carrot sailing', 3), ('hugs coin', 3), ('running pencil', 3), ('carrying foods', 3), ('quarter meaning', 3), ('margaret monster', 3), ("horse's monster", 3), ('spain papers', 3), ('driver drive', 3), ('dinosaurs nope', 3)]
# carrot sailing
# [('ouch forty seat bobby dot decorate', 2), ("cha icing number's guy raccoon wearing", 2), ('fifty peas yard scare actually smashing', 2), ('aislinn dollar jobs separate arms dad', 2), ('lisa peg wrapped ironing hospital climbed', 2), ("brushes three laura's sideways begins face", 2), ("white monsters she'll gently tick betty", 2), ('baseball pie toad kitten bites borrow', 2), ('drum killed wanted spray speaking brittany', 2), ("jump why're babe shirts horn ticklish", 2)]
# ouch forty seat bobby dot decorate
# [('works nee', 4), ('huge beds', 4), ('under collect', 3), ('sharing help', 3), ('rubbing waiting', 3), ('rip terrible', 3), ('switch hardly', 3), ('bib sesame', 3), ('tag matthew', 3), ('hat an', 3)]
# works nee
# [('sip rain triangles', 2), ('rug cupboard buy', 2), ('hamster santa pictures', 2), ('ate help twelve', 2), ('bread rocks definitely', 2), ('ram too january', 2), ('shop whale nope', 2), ('if anybody clever', 2), ('mustache win message', 2), ('bunny trunks buttons', 2)]
# sip rain triangles
# [('penguin cost boys bang puts problem', 2), ('bouncing wants ducks hotdog microwave swan', 2), ("lion's think yeh said making myself", 2), ("coal bagel go who're biscuit through", 2), ('rubber sound plug blankets stone desk', 2), ('blah seven goggins noah darling bounce', 2), ("kipper helicopter belt have flew sarah's", 2), ('himself sing gloves too drip plug', 2), ("sally street every mommy's checking during", 2), ("dad's hockey course straps sandy pump", 2)]
# penguin cost boys bang puts problem
# [("tune learn jason brum today's spring kitchen", 2), ("aw tubby colors didn't tracks woof arrow", 2), ("macdonald ay pretzel marky bird's songs robbie", 2), ('sticker smashing tub mariana steve poke somebody', 2), ('gone hopscotch see hippo bottles baked running', 2), ('realized smiling po fix sideways faster chocolate', 2), ("answer t mixing investigator moose yelling mark's", 2), ('carle temperature w reindeer cradle radiator shoes', 2), ('then sushi somewhere beaker gloves rhinoceros groceries', 2), ('promise valentine dolphin learned nobody crisp drivers', 2)]
# tune learn jason brum today's spring kitchen
# [('dun exercise love pippin mr', 2), ("gay proud they'll princess forty", 2), ('becky handle supermarket earth biscuits', 2), ('linda self doggy drums heavy', 2), ("painted morning it'll choice cowboy", 2), ('dan crackers scissors rings disgusting', 2), ('felt dive seemed bothered meg', 2), ('scott sorry pears en spain', 2), ('rectangle dillon bobo hafta see', 2), ('ross six granny buss teddy', 2)]
# dun exercise love pippin mr
# [('swiss bout', 4), ('ketchup sleep', 3), ('opened spade', 3), ('sailor plus', 3), ('click alley', 3), ('ross naw', 3), ('higher sale', 3), ('pat q', 3), ('boo seem', 3), ('tap cupcakes', 3)]
# swiss bout
# [('front tie', 4), ('hill dinner', 3), ('spots nancy', 3), ('screaming direction', 3), ('name dried', 3), ('kidding lobster', 3), ('shapes hours', 3), ('giraffe those', 3), ("they've best", 3), ('filling xylophone', 3)]
# front tie
# [('breath millions covered ears them', 2), ('bears pressed pushes ninety taste', 2), ("weeks sting creature jolly he's", 2), ('whoa blanket game hasta july', 2), ('ever stiff africa cutter goofy', 2), ('world sooty away igloo diaper', 2), ('slip papa toilet notes stack', 2), ('goes electric study closed january', 2), ("especially coach rachel's falls bits", 2), ('pretzel jack aislinn rid fur', 2)]
# breath millions covered ears them
# [("engine's alright", 4), ('instead shot', 3), ('watching crown', 3), ('beard z', 3), ('place hour', 3), ('superman robert', 3), ('pets diggers', 3), ("here's language", 3), ('dun cushions', 3), ('giraffes paw', 3)]
# engine's alright
# [('bear yum', 3), ('fairly eagle', 3), ('candles shampoo', 3), ('yet burger', 3), ('opens aid', 3), ('base jay', 3), ('downstairs ten', 3), ('buzzy crisp', 3), ('sneezing quietly', 3), ('cupboard everywhere', 3)]
# bear yum
# [('sugar scoot', 4), ('tools jar', 3), ('january yarn', 3), ('pony baby', 3), ('sings spoil', 3), ('heidi pips', 3), ('square cooker', 3), ('block rocky', 3), ('kangaroo denver', 3), ('dave female', 3)]
# sugar scoot
# [('ben sack', 3), ('jigsaw dive', 3), ('row slowly', 3), ('empty stairs', 3), ('yogurt honk', 3), ('ghost film', 3), ('beaker set', 3), ('sleeves flush', 3), ('roy dripping', 3), ('eggs barrette', 3)]
# ben sack
# [('seats pushing', 4), ('ginger firefighter', 4), ('crocodile lion', 3), ('hear really', 3), ('vitamins checking', 3), ('me whether', 3), ('it bend', 3), ('used windows', 3), ('grocery ian', 3), ('banana dots', 3)]
# seats pushing
# [('much backs', 3), ('practice xavier', 3), ('meal mailman', 3), ('joey sleeps', 3), ('remembered tee', 3), ('joking either', 3), ('living nathaniel', 3), ('glove have', 3), ('crib unusual', 3), ('dentist lock', 3)]
# much backs
# [('katie hard tricycle behave', 3), ('cowboys ambulance king vitamins', 2), ('third borrow correct when', 2), ('drum richard nanny octopus', 2), ('win rope chip sword', 2), ('ears rule loads puss', 2), ('parked engines words september', 2), ("double hasn't brings sky", 2), ('level ma circles ways', 2), ("win float itself she's", 2)]
# katie hard tricycle behave
# [("baker's ducks", 3), ('woken four', 3), ('chickens strawberries', 3), ('last between', 3), ('cooking nathan', 3), ('vitamin duh', 3), ('lily alex', 3), ('circus crying', 3), ('oil program', 3), ('park gary', 3)]
# baker's ducks
# [('germs beaker man february', 2), ('forgot elevator tickle grape', 2), ('bing less tables enjoyed', 2), ('behave catch powder touching', 2), ('master ways pu imagine', 2), ('trouble deal mustache borrow', 2), ('ribbon poop eggs night', 2), ('pail touching own mice', 2), ('tops museum whiskers muscles', 2), ('see chest stage used', 2)]
# germs beaker man february
# [('fast broke found', 2), ('pick twenty dropping', 2), ('mud doggy mo', 2), ('diapers spoons nuts', 2), ("rides bowling ben's", 2), ('clear zita okey', 2), ('four just part', 2), ('polite bout en', 2), ('win hanger eat', 2), ('possible doo acting', 2)]
# fast broke found
# [('minnie crocodiles fork siren passengers touching', 2), ('squash ladder brown hungry goose nap', 2), ('well fine c holiday quiet hi', 2), ('melissa world dr blowing when mixing', 2), ('melissa world dr blowing ballet mixing', 2), ("custard further else's pole landing dock", 2), ('happened cricket control wan someday clever', 2), ('waves sure page disappear pancake hundred', 2), ("laura's tell extra wonderful groceries butter", 2), ("witches err builder's mole dave doodle", 2)]
# minnie crocodiles fork siren passengers touching
# [('pinch toys', 3), ('brought heh', 3), ('keeper if', 3), ('ugly plus', 3), ('washing rug', 3), ('waved thousand', 3), ("linda's november", 3), ('slippers frog', 3), ('builder plaster', 3), ('bumpy giving', 3)]
# pinch toys
# [('do treasure', 3), ('five pie', 3), ('tomatoes was', 3), ('driver start', 3), ('weights fact', 3), ('trains block', 3), ('reached artist', 3), ('strip closet', 3), ('cold auntie', 3), ('late manchester', 3)]
# do treasure
# [('sandwiches bottles sheep', 2), ('indians march tasty', 2), ('realize skirt spiders', 2), ('simon bouncy mess', 2), ('shine toothpaste towards', 2), ('bonk g ups', 2), ('calf wrap someday', 2), ('lois toothpaste easy', 2), ('gimme soon stickers', 2), ('dumb hunt a', 2)]
# sandwiches bottles sheep
# [('rosie samantha', 4), ('pipe pretzel', 3), ('rod place', 3), ('melon too', 3), ('dots cooker', 3), ('skate bent', 3), ('tracy away', 3), ('certainly michael', 3), ('napkin hurray', 3), ('carries january', 3)]
# rosie samantha
# [('pumpkin bounce', 3), ('cool tasty', 3), ('soccer yup', 3), ('moon dried', 3), ('throwing lucky', 3), ('golden swing', 3), ('doodle carry', 3), ('kipper never', 3), ('nicer curly', 3), ('fred fit', 3)]
# pumpkin bounce
# [('using heh quarter hotdog', 2), ('shaped face cloud megan', 2), ('handsome pee hoo send', 2), ('brittany bozo afternoon sailboat', 2), ('shop l chris telephones', 2), ('dropped nah tow applesauce', 2), ("cows drip dolly's forgot", 2), ('roof pressed diapers marble', 2), ('cane hugs friday upon', 2), ('trap tickle accident graeme', 2)]
# using heh quarter hotdog
# [('barn dishes under', 2), ('boats five neither', 2), ("curls one's jigsaw", 2), ('cans listening snow', 2), ('opens able soil', 2), ('got nice certain', 2), ('treat skinny woods', 2), ('new helped says', 2), ("school anna's white", 2), ('ee army drill', 2)]
# barn dishes under
# [("mom's dust dock remote megan tag", 2), ('planet this pets feathers yarn sorry', 2), ("clifford stuart pirate children's isabelle cola", 2), ("hum invite octopus matthew let's cromer", 2), ('tip eric sandra rolled splashing stepped', 2), ('great fellow triangles gotta stepped fifth', 2), ("drill mark roads fallen nobody's better", 2), ('mixed giraffes infinity reach scarecrow beds', 2), ('plates books tracy decorations mayonnaise starting', 2), ('donald bubbles lauren bridge trap noisy', 2)]
# mom's dust dock remote megan tag
# [('date bo', 3), ('help mrs', 3), ('petrol stew', 3), ('faces lion', 3), ('fairly scoop', 3), ("awhile there's", 3), ('ruth somehow', 3), ('female lotion', 3), ('dey bowl', 3), ('dropping quit', 3)]
# date bo
# [("egg gordon's zita ten", 2), ('naomi tortoise hafta been', 2), ("round paul keys name's", 2), ('london remembered em god', 2), ("friend's butterflies briefcase bangs", 2), ('nick gravy dad pressed', 2), ('showing lower nuts triceratops', 2), ('shed comfortable peg whale', 2), ('seem taking soil motorbike', 2), ("dropping you'd again cows", 2)]
# egg gordon's zita ten
# [('tastes terribly', 4), ('le until', 4), ('onto cape', 4), ('bottles frightened', 3), ('eric noticed', 3), ('la punch', 3), ("one's rid", 3), ('muddy pumpkins', 3), ('owls tray', 3), ('pee gentle', 3)]
# tastes terribly
# [("stroller caroline's while", 2), ('el blue noah', 2), ('muddy could pah', 2), ('terrific parked memory', 2), ('tire birdies branch', 2), ('pickles bowl easy', 2), ('bad cab might', 2), ("church twist hadn't", 2), ('stretch koala sees', 2), ('pub sold restaurant', 2)]
# stroller caroline's while
# [('comfortable same tabitha', 2), ('bear driven turned', 2), ('coloring sausage enjoy', 2), ('first fairy scooter', 2), ('ha little newspapers', 2), ("hear hair's matches", 2), ('basement spider ribbon', 2), ('rolling control interesting', 2), ('sister poorly caught', 2), ('margarine hopscotch turn', 2)]
# comfortable same tabitha
# [('gopher porcupine pizza rhinoceros wash', 2), ("takes miss particular touching car's", 2), ('completely hear should doctor listen', 2), ("pins flag measure poured water's", 2), ('comb lake tacos knife jonathan', 2), ('pear skunk camping cat couch', 2), ('points used hulk such spitting', 2), ('keys care yum shelf hanging', 2), ('sore goats sticker san pardon', 2), ('office pinch buzzy beautiful sheet', 2)]
# gopher porcupine pizza rhinoceros wash
# [("drove kidding feathers spin circles feels wasn't tall zipper dock hoop besides market sooty zip pie", 2), ('zero edward eleven morgan pets flakes spade aunt peel sleigh swinging he knickers shaking storm surfing', 2), ('toast wondered factory looking lettuce took jess james holidays rubbish upstairs le wo pushed cars flash', 2), ('tunnel granola ears sticks frank deliver apple drum nom cricket denver cry edward carrots windmill seeing', 2), ("sudden gift address stopping straight one leaf toaster meat soldiers rhino triangles puddle alligator pork somebody's", 2), ('o itself fix steak law stop picked watermelon noah sing sofa only bertie jane barney long', 2), ("thomas's ladder lit test save ray wiped finishing spiders tricycle meaning toes jello pies regular plays", 2), ('torch diapers taller figure meeting squares equipment dave badge past carpet butt lady balls jenny ringing', 2), ("zoom covers harold september doll centre manage q daffodils baker's huh strawberries offer those sunday filling", 2), ('human mashed ladders sponge through whoop seemed batteries dumb bandage plain some milkshake brushes fat seemed', 2)]
# drove kidding feathers spin circles feels wasn't tall zipper dock hoop besides market sooty zip pie
# [('itchy out', 4), ('age beep', 3), ('cow held', 3), ('dryer raining', 3), ('stuffed twins', 3), ('goldilocks totally', 3), ('spend handsome', 3), ('err cotton', 3), ('spade policeman', 3), ('hairy cement', 3)]
# itchy out
# [('asked dalmatian clip farm', 2), ('use case close it', 2), ('mom flap ada nah', 2), ("lorry muscles doctor's bounce", 2), ('dumper comb corner paid', 2), ('wave quarters diet blackpool', 2), ('dolls heard thing chest', 2), ('lord cardigan clown lofty', 2), ('jingle bossy scott tractors', 2), ("hm granddad rabbit why's", 2)]
# asked dalmatian clip farm
# [('rosie straight garbage bertie emergency', 2), ("something telling into tiger's tomatoes", 2), ('learn crumbs stay february crane', 2), ('its my last hurrah swallow', 2), ('twelve bah ideas peck gun', 2), ('spilled lobsters behind pussy mans', 2), ('silver pinched smile maybe stop', 2), ('fairy pushing rough mine leg', 2), ('bunch plane interesting across bathroom', 2), ('barbecue jingle busy chin jigsaw', 2)]
# rosie straight garbage bertie emergency
# [('falls looking laid begins edges town birthday', 2), ("cow's are fruits pebbles five thousand parts", 2), ('panties star towel sledge milkshake offer cats', 2), ('pot harold dough mistake leaves like thirteen', 2), ('sneakers jelly chimney yucky bird mashed waiting', 2), ('toe drink buying peel grain ae candles', 2), ('brum spencer ripped yuck ate ducks closer', 2), ('bit blackpool funnel trick kneeling jingle stop', 2), ("loves careful they'd golden night bumble m", 2), ('keeping sweetheart swim grapes during swish fuzzy', 2)]
# falls looking laid begins edges town birthday
# [('bigger all claws', 2), ('plug rabbits coleslaw', 2), ('hugging feeding zoo', 2), ('birdie melted windows', 2), ('cleaner less work', 2), ('noticed tom crash', 2), ("action john how's", 2), ('won jigsaw shouting', 2), ('squirt miriam vitamins', 2), ('fork thinking missing', 2)]
# bigger all claws
# [("trumpet anne's", 3), ('falling apples', 3), ('usual tastes', 3), ('although blueberry', 3), ('of push', 3), ('bumps steps', 3), ('smashing grandma', 3), ('joy underwear', 3), ('cards swish', 3), ('sings jones', 3)]
# trumpet anne's
# [('nighttime dump pork', 2), ('max watched bubble', 2), ('umbrella farmer emergency', 2), ('break wipe dumper', 2), ("he'd behind t", 2), ('grade hammer monkey', 2), ('myself noise wish', 2), ('burned hammer brush', 2), ("summer farmer's dae", 2), ('moneys buns twenty', 2)]
# nighttime dump pork
# [('terribly cherry diaper carrying', 2), ('owls pain es coo', 2), ('alright x years plane', 2), ('female ripe drivers hon', 2), ('polish lettuce angel using', 2), ('beep scooter wanna pickles', 2), ('egg rex male others', 2), ('strap feels peanut moving', 2), ('visit whatever rain money', 2), ("brum fi tiger's mum's", 2)]
# terribly cherry diaper carrying
# [('cradle onions care', 2), ('church joseph puddle', 2), ('press carl cheer', 2), ("fraser's work office", 2), ('strip and case', 2), ('sort dinosaurs roland', 2), ('dey ages ear', 2), ('fall god broken', 2), ('picnic filled drive', 2), ('chopping carriage house', 2)]
# cradle onions care
# [('macdonald our dose', 2), ('dime thin nah', 2), ('very susan bananas', 2), ('cones war fifteen', 2), ('spitting whats sir', 2), ("apple bubbles he'll", 2), ('rex spanking carriage', 2), ('butcher edward cinnamon', 2), ('rob indian drinks', 2), ('ran hamburger ten', 2)]
# macdonald our dose
# [('toe cool', 4), ('surfing roller', 3), ('firemen ha', 3), ('boss bleeding', 3), ('cloth burp', 3), ('burned shaped', 3), ('got wind', 3), ('nickel wearing', 3), ('log gay', 3), ('path south', 3)]
# toe cool
# [("w donna platform pat's allen grade pretzels", 2), ('rolled bouncing puss heidi probably raisin carol', 2), ('turns mud hats brought windmill swims paint', 2), ('bicycle ducky crawl steve sweets bump bringing', 2), ('chairs tractor chase raisin race right each', 2), ("stronger adam's weren't steady mending properly awesome", 2), ('cave seems stopping drag coming nights walk', 2), ('tummy ironing worth drinks thunder able w', 2), ('raisins dave order pictures shoulder mini happen', 2), ('seeing guess humpty judy mouse shining claus', 2)]
# w donna platform pat's allen grade pretzels
# [('pence roads held stroller ah pushes', 2), ('sled forks rubbish elevator out on', 2), ('wheat worth tee seems mother spiderman', 2), ('songs fall empty used photographs hiccups', 2), ("string napkin lying properly she's ordinary", 2), ('meet jessica somebody dresses firefighter wall', 2), ('tune annie tummy sunflower likes ice', 2), ('follow eighteen feeling plain catch lived', 2), ("orange dried sticks mother great why're", 2), ('biscuit carried recording buddy absolutely bulldozer', 2)]
# pence roads held stroller ah pushes
# [('julian squirrels right', 2), ('bottles glad jello', 2), ('fair bull ladies', 2), ('gopher munch was', 2), ("go fifty brian's", 2), ("doggy's coke piles", 2), ('trousers pipes eleven', 2), ('feathers proud black', 2), ('deal ketchup lucy', 2), ('catherine faces megan', 2)]
# julian squirrels right
# [('ladders died oy', 2), ('bella chicken penguin', 2), ('cherries syrup dan', 2), ('seed pavement protect', 2), ('motor bethany balloon', 2), ('passengers more raspberries', 2), ('label wake november', 2), ('logs pine itself', 2), ('played roundabout neat', 2), ('wipes bong lovely', 2)]
# ladders died oy
# [('sounded haw ask', 2), ('seats sharing small', 2), ('patrick funny post', 2), ('anna crack aaron', 2), ('clip helmet oliver', 2), ('helmet sky twins', 2), ('stop movies biscuits', 2), ("awesome terribly linda's", 2), ('flags mountain sammy', 2), ('tidy fix can', 2)]
# sounded haw ask
# [('yellow doctors dah crabs', 2), ('wedding bored airplanes bags', 2), ('catch doodle gee crunch', 2), ('bo sailor baa poorly', 2), ('fairly elephants help pat', 2), ('pouring bubbles tubby jump', 2), ('laughing keep container powder', 2), ('cheeky ladybug stones mama', 2), ('dining pay mommy small', 2), ('tired string force others', 2)]
# yellow doctors dah crabs
# [("read yoyo keeping andy's jingle", 2), ('juice frosting tread hey goes', 2), ('teach we carrots male dog', 2), ('pans luke afraid doctors flies', 2), ('alley interesting self dumpty notice', 2), ('berries doc skates friend pussy', 2), ('yellow rectangle dust wagon town', 2), ('fruit knitting grab hat without', 2), ('everything bib sticky faster walrus', 2), ('worth build bored wide picking', 2)]
# read yoyo keeping andy's jingle
# [('working let gosh heat remind', 2), ('bozo undo crayon start tickle', 2), ('anyway hoping quit turn laurie', 2), ('rachael carle at kids mayonnaise', 2), ('crunch diapers bathing dear fizz', 2), ("tiger's baker's peek study awfully", 2), ('did sonia whoo seat losing', 2), ('camp keeping medicine up beaker', 2), ('recently sweets airport tablets walking', 2), ('sew sense cuddly peek uh', 2)]
# working let gosh heat remind
# [('king gimme grown', 2), ('jill loo watermelon', 2), ('forest trousers wreck', 2), ('nose neighbors cluck', 2), ('business gail pippin', 2), ("dog's tells jennifer", 2), ("someone's sara baa", 2), ('switch last as', 2), ('sandra towards upset', 2), ("smash sarah's snake", 2)]
# king gimme grown
# [('norman alley', 4), ('decided gotta', 3), ('cannot least', 3), ('went ham', 3), ('newspaper charlie', 3), ('indeed tipping', 3), ('left cereal', 3), ('toys bottles', 3), ('telephones music', 3), ('seal dream', 3)]
# norman alley
# [('lately slug', 4), ('steak napkins', 4), ('leg nut', 4), ('pizza andrew', 3), ('shout indeed', 3), ('yummy grapes', 3), ('three works', 3), ('beef gingerbread', 3), ('grass thought', 3), ('war pastry', 3)]
# lately slug
# [("sharks sign pat's ours digging", 2), ('adam tastes drawers bored my', 2), ('riding paddington parrots der piece', 2), ('cream gail kicking steady faster', 2), ('easily old making sled sandwiches', 2), ("eleanor's louder piggy rest wiggle", 2), ('hotdog rachael bouncy bro polish', 2), ('go us slipped doing lives', 2), ('ladybird twenty form spilt jean', 2), ('taller decide fence play horrible', 2)]
# sharks sign pat's ours digging
# [("hoop mightn't judy date", 2), ("shouldn't remember exercises oughta", 2), ('poke e crib cents', 2), ('computer porch pounds half', 2), ('check spring okey thirteen', 2), ('barking black cartoons meeting', 2), ("mariana attack girl's ta", 2), ('pirates win photograph flowers', 2), ("mummy's milkman sam ripped", 2), ("lids pin baby's yuck", 2)]
# hoop mightn't judy date
# [('amy go garbage', 2), ('fan jingle shovel', 2), ('world rattle tower', 2), ('bench to salad', 2), ('problem dust alligator', 2), ('hotdog ow squishy', 2), ('radiator wheelbarrow elmo', 2), ('deedee whenever steering', 2), ('mhm honk kent', 2), ('gee enough match', 2)]
# amy go garbage
# [('timer christa high closed strawberry', 2), ('smarties muffins lipstick yup paw', 2), ('hand cupboard strange so near', 2), ('flower round given buzzy fuss', 2), ('peggy playing mushrooms cage enjoying', 2), ('bud scott dan luke aye', 2), ("telephones shoulders i'd raspberries street", 2), ("they're crane dumbo haw paper", 2), ("dinner that'll closet cradle somehow", 2), ('allen birthday dripping wrapped bone', 2)]
# timer christa high closed strawberry
# [('vegetables hunt', 4), ('raisins slides', 3), ('jet yarn', 3), ('voice jumps', 3), ("spell bear's", 3), ('alexander terribly', 3), ('why hearts', 3), ('filled hat', 3), ('stories thinking', 3), ("kings train's", 3)]
# vegetables hunt
# [("doing grownups guy's", 2), ('cats london write', 2), ('octopus crumbs diamond', 2), ('besides point whatever', 2), ('row jen zero', 2), ('bells ghost smoking', 2), ('bean graham grape', 2), ('emma mind owe', 2), ('weight millions junk', 2), ('calendar lots buy', 2)]
# doing grownups guy's
# [("didn't aran kneeling", 2), ('packet skin slipper', 2), ('showed telly pu', 2), ('coming heads beep', 2), ('plastic silly windmill', 2), ('walk eaten eighty', 2), ("sideways there'll stops", 2), ('dressing cloud restaurant', 2), ('clock pea butcher', 2), ('calling smash gross', 2)]
# didn't aran kneeling
# [('thank mike', 3), ('why lost', 3), ('blonde cucumber', 3), ('goldfish apple', 3), ('state stroke', 3), ('split spread', 3), ('louise recognize', 3), ('hush nest', 3), ('forest bobble', 3), ('king laurie', 3)]
# thank mike
# [('skates nope tacos', 2), ('very letting character', 2), ('carle easier saturday', 2), ('string might piggy', 2), ('mistake seconds starting', 2), ("wobble third why're", 2), ('pots postman caterpillars', 2), ('roses rhymes instructions', 2), ('snail taking brush', 2), ("biscuit windy mummy's", 2)]
# skates nope tacos
# [('remembered there other', 2), ('happened kings nicely', 2), ('purse beets writing', 2), ('wicked carol magnetic', 2), ('wicked carol trying', 2), ('channel drawn soil', 2), ('headache hand baked', 2), ('teddy wish dripping', 2), ('mistake robert chick', 2), ('bonk wipe baba', 2)]
# remembered there other
# [('movies bushes', 3), ('liked spiderman', 3), ('costume gail', 3), ('bars lookit', 3), ('gentle hula', 3), ('hen aaron', 3), ('die screw', 3), ('surprised treasure', 3), ('kitchen waiting', 3), ('das ladybird', 3)]
# movies bushes
# [('they granny oliver basket papers', 2), ('pretty properly paying hang killed', 2), ('frightened closer smarties bambi kill', 2), ("alive knot donkey asked brother's", 2), ("there'll martin maybe spells cloth", 2), ("burnt ballerina tin you'd san", 2), ("building quiet i'll gordon maybe", 2), ('came cutting suit shoo giraffes', 2), ('faster summer ages accident billy', 2), ('screaming girl did cheer nail', 2)]
# they granny oliver basket papers
# [("figure policeman's newspapers vacuum super barrel", 2), ('banging begin bag graham party died', 2), ("rolly rectangle lines boy's crocodiles hiccups", 2), ("wears followed safe meat we've november", 2), ('robert birdie bears lizard trousers downstairs', 2), ('pirates lift broke chasing dry along', 2), ('get fuzzy wears stopping teapot wiped', 2), ("bonk we'll loose dots superman friend's", 2), ('queen pancake ray curls tripped janet', 2), ('buggy upon eleven greens bert tablets', 2)]
# figure policeman's newspapers vacuum super barrel
# [('spilled warren', 4), ('board drops', 3), ('finally hold', 3), ('robot nights', 3), ('stepped curtain', 3), ('ray thought', 3), ('swimming brand', 3), ("we've every", 3), ('barney polar', 3), ('roundabout tires', 3)]
# spilled warren
# [('fishing ends', 4), ('but small', 3), ('tire pens', 3), ('texture rocks', 3), ('shooting naw', 3), ('factory harold', 3), ('dare jackie', 3), ('rattle life', 3), ('tricycle head', 3), ("paw someone's", 3)]
# fishing ends
# [("landed rubbish played farmer's", 2), ('dingo married dime place', 2), ('sir pens ada luke', 2), ('grade cooking ryan favorite', 2), ('slice lines bobble funny', 2), ('regular lolly ursula smooth', 2), ('bum kindergarten apparently careful', 2), ('calendar no pony roll', 2), ('tap pickle fingernails low', 2), ('another marching no hers', 2)]
# landed rubbish played farmer's
# [('rocking tape harry wobble boxes anne', 2), ('traffic surprised much robert taller shark', 2), ('nobody biggest already jane yo cream', 2), ('doctor lady s isabelle becky hoping', 2), ('second diesel places dr jam butterflies', 2), ("baker megan wow jumping sarah there're", 2), ('naomi blueberry building marmalade alligators cross', 2), ("sun's jello potato wife juice in", 2), ('plug birdie thirteen cars lessons spank', 2), ('whatever hippo laying outside michael fields', 2)]
# rocking tape harry wobble boxes anne
# [('net pox cardigan fact cowboy', 2), ("tray helicopter would've stew coat", 2), ('throw squash year return zoe', 2), ("ye blue's bee kittens leg", 2), ('oven shaped god puts call', 2), ('fizz ballerina wendy ruth restaurant', 2), ('chi ever does oop restaurant', 2), ('ceiling giraffe sell english warren', 2), ('oven feed spells dah geese', 2), ('swiss lee definitely ladybugs places', 2)]
# net pox cardigan fact cowboy
# [('oil winner', 4), ('sand odd', 4), ('wee anne', 3), ('socks waffle', 3), ('dot slice', 3), ('older kicking', 3), ('kate upset', 3), ('branches hundred', 3), ('wiggle tire', 3), ('somebody board', 3)]
# oil winner
# [('ribbit young lonely', 2), ('patty flashlight twins', 2), ('seem cubes part', 2), ('hid nut given', 2), ('blind seat elmo', 2), ('ahead lo freezer', 2), ('buzz caitlin baking', 2), ('teasing forgot clown', 2), ('factory baseball grumpy', 2), ('grow cheek hay', 2)]
# ribbit young lonely
# [('ripe spread hid sister choo', 2), ('soldiers whether max vest cloth', 2), ("peanuts tank they're woke without", 2), ('bulldozer almost sewing splashed anthony', 2), ("lines very whole popcorn bear's", 2), ('shows remind lo yikes stroller', 2), ('skates up teach visit bark', 2), ("teething couch farmer's rip step", 2), ('apple under aerobics butter bless', 2), ('dinosaurs red always alex seek', 2)]
# ripe spread hid sister choo
# [('duh are julia tail birdies jigsaw second a awesome', 2), ("they're pretending microwave wiping puppets wheels drank an pan", 2), ('martin add ho dryer dose everytime dear color pans', 2), ('bed daw wanting wondered underwear brick nasty feel dinosaurs', 2), ("notice bars november finds name's dusting high apple hose", 2), ('cowboy dream loose frosting papa buddy horn drivers pajamas', 2), ('lately program olivia tweet polish pancakes chicken should wrist', 2), ('dirty postman swan bathing snacks vanilla ant oughta tail', 2), ('controller missing cane alarm stole asked traffic shelf says', 2), ('park calf hoop talks knitting usually saturday water tight', 2)]
# duh are julia tail birdies jigsaw second a awesome
# [('oh win', 4), ('except lala', 3), ('nurse crunch', 3), ("grows brother's", 3), ("breaks mum's", 3), ('cookies to', 3), ('bandage apparently', 3), ('grace paddington', 3), ('pumpkins cuddle', 3), ('vegetable ache', 3)]
# oh win
# ...
# hafta mothers
# [('eleanor jungle hiding', 2), ('ten takes towards', 2), ('does shows weeks', 2), ('dey pinched smelling', 2), ('clean benjamin judge', 2), ('rinse shut normal', 2), ('sticky washer hoover', 2), ('nice watches married', 2), ('towels sunglasses pressing', 2), ('decided winnie mixing', 2)]
# eleanor jungle hiding
# [('pins snowing diaper', 2), ('seed achoo ache', 2), ('songs hockey goes', 2), ('minute closing window', 2), ('artist listening follow', 2), ('wanna starts hay', 2), ("hi elephant's aislinn", 2), ('cap steal nina', 2), ('quarter creams dunno', 2), ("piles package you'll", 2)]
# pins snowing diaper
# [('ostrich ticket', 3), ("ribbon should've", 3), ("wore mcdonald's", 3), ('feathers tricky', 3), ('cupcakes dr', 3), ('exercise oil', 3), ('din no', 3), ('half celery', 3), ('nobody there', 3), ('colors curls', 3)]
# ostrich ticket
# [('yell magnets licking aye scratch pretzel taste', 2), ("woods cheating bossy baba we'll wight planet", 2), ('talk tank meet grade pulled es peach', 2), ('jeep pages jolly mcdonalds machines came collecting', 2), ("honey roads found cover et something's register", 2), ('felt frosty loose knot town prince bean', 2), ('buildings bicycle you spells dripped triangle glasses', 2), ('quarter goofy briefcase tickets come husband dip', 2), ('dragon use grew hairy dumb poorly coleslaw', 2), ("rain aerobics planted jean lounge dolly's caterpillar", 2)]
# yell magnets licking aye scratch pretzel taste
# [('grandma tumble sorts', 2), ('dear had gorilla', 2), ('spitting thanksgiving offer', 2), ('living cuddle cola', 2), ('raspberry drinking boy', 2), ('most bib t', 2), ('allen ballet holds', 2), ('sounded bright us', 2), ('whoever annie dan', 2), ("junior spilled rachel's", 2)]
# grandma tumble sorts
# [('sweater carry', 4), ('pass apple', 4), ('grown beautiful', 3), ('our left', 3), ("nicole mustn't", 3), ('rolls edges', 3), ('sleigh places', 3), ('smiley cats', 3), ('sword finished', 3), ('looking toe', 3)]
# sweater carry
# [('ways first', 4), ('give helped', 3), ('looked dokey', 3), ('slippery prefer', 3), ('broke moose', 3), ('watched hand', 3), ("mash mcdonald's", 3), ('asleep ty', 3), ('meat bank', 3), ('vitamins camping', 3)]
# ways first
# [('teething tear', 3), ('boring bethany', 3), ('full brush', 3), ('dropped crane', 3), ('beach inside', 3), ("waffles bird's", 3), ('spank later', 3), ('dick sean', 3), ('supper wonderful', 3), ("needed fraser's", 3)]
# teething tear
# [("sense needed train's class brave tables pretending", 2), ("dingo alphabet poppy weren't fancy french dizzy", 2), ('written camp bug works lifting louise drew', 2), ("i ripe splash anywhere pig's for tummy", 2), ('wall apples balloons yo before sun ye', 2), ("sliding usually thinks peoples that's completely you'd", 2), ('thin wave nail used remember junior foods', 2), ('lines jesus bikes pictures cook daddy alice', 2), ("takes sing july andrew gray when's fits", 2), ('tubby february mr bags norman stops nicer', 2)]
# sense needed train's class brave tables pretending
# [("practice carrots bedtime pay puppies bear's turned john's speaking peach how'd mommy's school", 2), ('cheek carefully bears station stepped ribbon trade posting wiggle feel dust boom simple', 2), ("boop taking shopping driver's lisa wrap packed cried present trade christopher joy percy", 2), ("bother cries there'll stretch evening bugs note carl cradle surfing xylophone sally raccoon", 2), ("henry's enjoying stopped cough joseph puppets broken coco fussy female protect ne only", 2), ('sorted candles fuss hugging parked strip shower corn photo properly find along breakdown', 2), ('nick go boston bethany microwave shouted birds cushions hair bunny forks granddad remember', 2), ('fruit wo panda chip gives pump pittsburgh n other large megan gobble snoring', 2), ("mop burned heat they'll margaret grandmother depends vitamin chug few yum bug favorite", 2), ("cinnamon burned expensive bud thank breakfast knives putting mushroom count mightn't pin cinnamon", 2)]
# practice carrots bedtime pay puppies bear's turned john's speaking peach how'd mommy's school
# [('chance wrapping poorly', 3), ('table cement what', 2), ('lion eel sledge', 2), ('toddler tall d', 2), ('bag loo ramp', 2), ('quit yarn touch', 2), ('tripped tortoise tomatos', 2), ('grass flower dick', 2), ('creatures pipe smaller', 2), ('splinter awake forth', 2)]
# chance wrapping poorly
# [('christa cabbage nanny places brown jonathan sport bare until joke', 2), ('fight tag w indeed boring twist spoons wing t pink', 2), ("bandaid buzzy perfectly hat toothpaste seemed falls shaking train's knot", 2), ('easily poppy turns whoops meant claus smells car spray pipes', 2), ("blew chi's willie him story curtain south eighty shouting excuse", 2), ('pens lamp blowing amazing exercises cabbage news pub kinda apples', 2), ("robot you'd bored yo strange lump aye cheek triceratops others", 2), ("checked kiss hip cards aah dingo poo dolphins mcdonald's beak", 2), ("packed rocket heidi tabitha wes twice coffee mush better doctor's", 2), ("maggie denver nicola nails ah bear bob's carefully buying pepper", 2)]
# christa cabbage nanny places brown jonathan sport bare until joke
# [('neighbor tusks sean were', 2), ('dave decorations tops hunt', 2), ('dream drew saucer peanuts', 2), ('frosting cereal claws teeth', 2), ("pens charlotte's look snow", 2), ("loud tim name's most", 2), ("where'd caitlin splinter roy", 2), ('another nurse wakes dan', 2), ('pool swiss mr cock', 2), ('across luck el speed', 2)]
# neighbor tusks sean were
# [('bits key sail taking seek erica airport', 2), ("sister's songs tiny names mom's whispering zoe", 2), ("barbecue ugly shaking key alphabet driver's puppets", 2), ('baa lets stamp delicious cats finished cocoa', 2), ("seals twins mightn't bit pocketbook snail book", 2), ("milkshake beak clay pipes train's aerobics woof", 2), ('sharing sorted does others teapot present pies', 2), ('lily sheeps photo pencil lemme seven holly', 2), ('runny church bozo cook shiny war downstairs', 2), ('waste jolly red trip gave die expect', 2)]
# bits key sail taking seek erica airport
# [('tricky when', 3), ('name feel', 3), ('forest cries', 3), ('chew pah', 3), ('meet were', 3), ('mr neighbors', 3), ('gasped willie', 3), ('form mhm', 3), ('blonde carey', 3), ('mines ladybird', 3)]
# tricky when
# [('till trunk', 4), ('pants mountain', 4), ('switch floor', 3), ('nah floor', 3), ('spanking came', 3), ('underwear beat', 3), ("happening mine's", 3), ('sentence reach', 3), ('felix coach', 3), ('toad cheer', 3)]
# till trunk
# [('fi early match ambulance sip bedroom all', 3), ('lamp et james pardon right bottom doctor', 2), ('wood stinky someone soda swing horses feels', 2), ('wire sand och yay railroad in barn', 2), ("that's capital claws birthday guns barber regular", 2), ("knife wing that'll jen collar quickly knives", 2), ('easter roland notes mushrooms trees woods joseph', 2), ('cause ugly heidi berries need pony toilet', 2), ("handle he freezer weird if spray sarah's", 2), ('message fat pajamas sledge coke aw ram', 2)]
# fi early match ambulance sip bedroom all
# [('as boiled', 4), ('drinks ruth', 3), ("there'll making", 3), ("gail's tricky", 3), ('stepping beach', 3), ('regular bozo', 3), ('crawl smell', 3), ('bonk but', 3), ("girl's clip", 3), ('sledge fairy', 3)]
# as boiled
# [('jesus hotel', 3), ('near fi', 3), ("mother's pillow", 3), ('scooter at', 3), ('pants scooter', 3), ('robert shop', 3), ("d her's", 3), ('called regular', 3), ('dustbin worth', 3), ('plug tins', 3)]
# jesus hotel
# [('julie different', 3), ('gets grey', 3), ('peanuts saved', 3), ('spilled africa', 3), ('jar began', 3), ("he'd indians", 3), ('digger horns', 3), ('whoo pad', 3), ('mood hotdog', 3), ('job wore', 3)]
# julie different
# [("brooklyn worried fireplace sitting tops crunch chick fraser's dobbin raccoon pen", 2), ("eye potato shame dryer mister slippers person anymore tiger's custard am", 2), ("mummy uncle calling camel legs t salmon flying duck's poured nowhere", 2), ("timmy donkey freezing neck mine's cherries followed carriage film ow whenever", 2), ("charlie afraid he's missus asked he's dump frosty alphabet star march", 2), ('sixty ruth walk patrick mad hers bedroom winnie uh seen flew', 2), ("quack cut clues ballerina lady's grain opening peek boo clever given", 2), ('decide tractors minute wow beetle comfy crane tiny fifty newspapers wearing', 2), ("raisin it'd grand add bangs skirt spots pumpkins nee police hiding", 2), ("written acting behave must've fell cement egg boxes shorts boring here's", 2)]
# brooklyn worried fireplace sitting tops crunch chick fraser's dobbin raccoon pen
# [('fixed painting beds bump correct', 2), ('pancake rest no math popeye', 2), ('mended wait thin steam sliding', 2), ('bathing weight stretch okay scream', 2), ('knot egg woken vroom needed', 2), ("trunks i'd stripes simple carried", 2), ("smash packet except cow's mines", 2), ('skunks sick ribbon opens greedy', 2), ('bookcase recorder jingle birds gift', 2), ('feather suck plus slides creams', 2)]
# fixed painting beds bump correct
# [('made roared', 4), ('mailman free', 4), ('baba difficult', 4), ('simon granola', 3), ('medicine judge', 3), ('grandpa auntie', 3), ('dunno woody', 3), ("where's dance", 3), ('rain tomorrow', 3), ('thing please', 3)]
# made roared
# [('gordon fussy doggie mum', 2), ("rainbow mom's sean rug", 2), ("chi though he'll wiggly", 2), ('enough engines wind forth', 2), ('cigarette kathy would pen', 2), ('games stronger tag fast', 2), ('sheeps ribbit swallow difference', 2), ('decided starfish ours ark', 2), ('smashed wasp lip separate', 2), ('bathtub weights plate open', 2)]
# gordon fussy doggie mum
# [('hen koala first follow', 2), ("nobody's pitcher order peter", 2), ('drop duckies awful patrick', 2), ('took caitlin pirates smiling', 2), ('ambulance friday boats nineteen', 2), ('force roller marbles anymore', 2), ('job chicks sing wife', 2), ('crunch already letting cloud', 2), ('monsters turkey fuzzy our', 2), ('sledge in seem played', 2)]
# hen koala first follow
# [('cape diesel save helmet tweet peter', 2), ('to boss idea anne island brushes', 2), ('tops gloria noise bug day zoom', 2), ("mr roar wanted pear head's nom", 2), ('had nicer maggie hooray alive wrapping', 2), ('house neck squirrels gun store sent', 2), ('changing mood off needed normally keeps', 2), ('coke needs tv handsome scarf bash', 2), ('away cardboard saying lines ladybird anne', 2), ('catherine race f vader wight papa', 2)]
# cape diesel save helmet tweet peter
# [('mia pops thin safe', 2), ('helps chalk cinnamon tip', 2), ('jet during okay dress', 2), ('lamb bricks brush plum', 2), ('marmalade guys xavier giraffe', 2), ('muddy dub sign scotland', 2), ('september catch yup clowns', 2), ('if amen jack today', 2), ('chewing month eats elmo', 2), ("horses school you're talks", 2)]
# mia pops thin safe
# [('percy closet observer', 2), ('grabbed channel patio', 2), ('katie ours shovel', 2), ('dakota easily guard', 2), ('skinny easy wobble', 2), ('stopping penny sara', 2), ('wet clues sail', 2), ('thank o milkman', 2), ('tick borrow rules', 2), ('puppy cards jen', 2)]
# percy closet observer
# [('whoo jingle pets', 2), ('dumper exercises pulled', 2), ('football sell kitchen', 2), ('god wake chug', 2), ('band jellyfish gorgeous', 2), ('icing sticking eel', 2), ("children's photographs excellent", 2), ('totally space what', 2), ('lesson or huh', 2), ('ladybugs poured realize', 2)]
# whoo jingle pets
# [('mush key already food', 2), ('brum year jeans bones', 2), ('vroom nighttime pick flash', 2), ('laying triangle keeping wheat', 2), ('years cab feeding wes', 2), ("comes fee pumpkins won't", 2), ('knocked dae chickens postman', 2), ('hula boy call lifting', 2), ("sister's grumpy done fancy", 2), ('camera bunch flat further', 2)]
# mush key already food
# [('stand gold', 4), ('probably whoop', 4), ('prefer salad', 3), ('bash saturday', 3), ('winner kite', 3), ('doughnut dreams', 3), ('dave play', 3), ('telly ballerina', 3), ('chopping jacket', 3), ('lamp anna', 3)]
# stand gold
# [('firefighter ugh nicola', 2), ('wednesday itself sheet', 2), ('finding grape ted', 2), ('slept wire earlier', 2), ('isabel mix piles', 2), ('although sticky finished', 2), ('seemed dig sucking', 2), ('long bake went', 2), ('pretzel doggies fairy', 2), ('times dish humpty', 2)]
# firefighter ugh nicola
# [('grabbed enjoying rid', 2), ('counter lego greens', 2), ('pilot mushrooms smells', 2), ('hungry bottles furry', 2), ('sisters steady yoyo', 2), ('laugh wheel whales', 2), ('spinach iron denver', 2), ("eh my her's", 2), ('london note mop', 2), ('goodness colors planted', 2)]
# grabbed enjoying rid
# [('themselves ladder', 4), ('keeps hole', 3), ('chest ada', 3), ('es puddle', 3), ('tommy writing', 3), ('ruler loud', 3), ('dave everywhere', 3), ('whales tire', 3), ('instructions asian', 3), ('shot afraid', 3)]
# themselves ladder
# [('sophie taught envelope tastes', 2), ('truth yuck princess hippopotamus', 2), ("ladybug anna's hose cleaned", 2), ('dolphin george guard hug', 2), ('mittens spilt jumper smashing', 2), ('groceries bulldozer banana waves', 2), ("tapes why're said california", 2), ('pah donna pineapple busy', 2), ('spell africa protect secret', 2), ('girl switch warm bite', 2)]
# sophie taught envelope tastes
# [('bro cheating carpet matches recognize twenty', 2), ('gulp cave anyone bedroom tuesday whisper', 2), ('even snap england laid begin hedgehog', 2), ('together creature reason piles quiet helicopter', 2), ("balloons tesco maggie's airplane bulldozer shall", 2), ('lifted until prince white eater jumping', 2), ('food york places mark thousand whoosh', 2), ('fourteen shock bracelet letter pencil mustache', 2), ('giraffe fixing bats chocolate dots ram', 2), ('applesauce comfy pie turning carle stacking', 2)]
# bro cheating carpet matches recognize twenty
# [("isn't salt sweets", 2), ('prefer scratched pooh', 2), ('graham sisters thrown', 2), ("charlotte's boat gates", 2), ("buzz sticking teddy's", 2), ('hers watermelon building', 2), ('naughty houses climb', 2), ("what've amazing saw", 2), ('doing motorbike bleeding', 2), ("wouldn't exercise ram", 2)]
# isn't salt sweets
# [("farmer's bandage diet et", 2), ('chain weeds teasing jelly', 2), ('go how begin ever', 2), ('laura dot washing radiator', 2), ('far bake passenger banana', 2), ("i'll twist ball gets", 2), ('thank bricks icing wise', 2), ('be pitcher crib tight', 2), ('comfy dinosaur fix snoring', 2), ("drag train's pattern often", 2)]
# farmer's bandage diet et
# [('some scream', 3), ('let told', 3), ('cheeky breathe', 3), ('corn jumps', 3), ('hoops grapes', 3), ('oliver awake', 3), ("teddy's mud", 3), ('traffic asian', 3), ('steve tickles', 3), ('set ne', 3)]
# some scream
# [("henry's another others", 3), ('die slice teddy', 2), ("town jungle doesn't", 2), ('walks towers buns', 2), ('scribble feeling helped', 2), ('soldier julia washed', 2), ('size least goose', 2), ("julie how's way", 2), ('tops chickens dollars', 2), ('snoopy wiggly kinds', 2)]
# henry's another others
# [("friend's fits", 3), ('bridge bull', 3), ('sneakers nice', 3), ('enough floor', 3), ('lap eat', 3), ('shit keys', 3), ('papa puzzles', 3), ('meal potato', 3), ('cloud racing', 3), ('seems sick', 3)]
# friend's fits
# [('bakery promise', 3), ('grab spinning', 3), ('carrots stepping', 3), ('else spanner', 3), ('address papa', 3), ('things snails', 3), ('phones grade', 3), ('act toys', 3), ('broom tune', 3), ('porch wing', 3)]
# bakery promise
# [('barry lessons bull', 2), ('want bumped ted', 2), ('upset watering radiator', 2), ("everything's ian obviously", 2), ('language friday giraffe', 2), ('off bert winnie', 2), ('itself mcdonalds fat', 2), ('huh cabbage scratch', 2), ('et feels snap', 2), ('send chicks send', 2)]
# barry lessons bull
# [('desk tortoise gail', 2), ('bumpy kevin pull', 2), ('bend shake spaceship', 2), ('stories straight birth', 2), ('joy hats notice', 2), ('ice bud protect', 2), ('york bother fifty', 2), ('broken brain leave', 2), ('mandy controller coco', 2), ('heard groceries cash', 2)]
# desk tortoise gail

# %%
new
# Out:
#            id                        gloss            stem  \
# 0    17498348                         uhoh            uhoh
# 1    17306905                   where blue      where blue
# 2    17608013  grizzly+bear a grizzly+bear               a
# 3    17466822              what's his name   what his name
# 4    17305483                     Gigi try        Gigi try
# ..        ...                          ...             ...
# 495  17352007               crack a bottle  crack a bottle
# 496  17489283                   it's Santa        it Santa
# 497  17453154                  with auntie       with aunt
# 498  17611350           what's Mommy doing   what Mommy do
# 499  17466108              what's her name   what her name
#
#              actual_phonology            model_phonology         type  \
# 0                         əhæ                       ʌ oʊ  declarative
# 1                       wɛ bu                   wɛɹ bluː     question
# 2    hʊði beɪ^ə ə ɡwɪðli beɪə  ɡɹɪzliː bɛɹ ə ɡɹɪzliː bɛɹ  declarative
# 3               wəts hɪz neɪm              wʌts hɪz neɪm     question
# 4                   titi twaɪ                ʤiːʤiː tɹaɪ  declarative
# ..                        ...                        ...          ...
# 495                kʌk ə bɑbɑ               kɹæk ə bɑtəl  declarative
# 496                 ɪd sæ̃ndɑ                  ɪts sæntə  declarative
# 497               wɪs ɑːn^tʰi                  wɪθ æntiː  declarative
# 498             wʌz mɑmi duɪn           wʌts mɑmiː duːɪŋ     question
# 499           wʌːts hɜ˞r neɪm              wʌts həɹ neɪm     question
#
#     language  num_morphemes  num_tokens  utterance_order  ... collection_id  \
# 0        eng              1           1              193  ...            21
# 1        eng              2           2             1414  ...            21
# 2        eng              1           3             1060  ...            21
# 3        eng              4           3                8  ...            21
# 4        eng              2           2              477  ...            21
# ..       ...            ...         ...              ...  ...           ...
# 495      eng              3           3              298  ...            21
# 496      eng              3           2              588  ...            21
# 497      eng              3           2              109  ...            21
# 498      eng              5           3              959  ...            21
# 499      eng              4           3             1322  ...            21
#
#     corpus_id speaker_id target_child_id transcript_id  \
# 0         336      23495           23495         43379
# 1         336      23471           23471         43236
# 2         336      23510           23510         43468
# 3         336      23495           23495         43370
# 4         336      23471           23471         43246
# ..        ...        ...             ...           ...
# 495       336      23487           23487         43275
# 496       336      23495           23495         43375
# 497       336      23495           23495         43356
# 498       336      23510           23510         43447
# 499       336      23495           23495         43357
#
#                                 ipa_sentence  adjusted_model_phonology  \
# 0                                ['ə', 'oʊ']                      ə oʊ
# 1                             ['wɛɹ', 'blu']                   wɛɹ blu
# 2    ['ɡɹɪzli', 'bɛɹ', 'ə', 'ɡɹɪzli', 'bɛɹ']   ɡɹɪzli bɛɹ ə ɡɹɪzli bɛɹ
# 3                    ['wəts', 'hɪz', 'neɪm']             wəts hɪz neɪm
# 4                           ['ʤiʤi', 'tɹaɪ']                 ʤiʤi tɹaɪ
# ..                                       ...                       ...
# 495                   ['kɹæk', 'ə', 'bɑtəl']              kɹæk ə bɑtəl
# 496                         ['ɪts', 'sæntə']                 ɪts sæntə
# 497                          ['wɪθ', 'ænti']                  wɪθ ænti
# 498                 ['wəts', 'mɑmi', 'duɪŋ']            wəts mɑmi duɪŋ
# 499                  ['wəts', 'həɹ', 'neɪm']             wəts həɹ neɪm
#
#                   transcripted_from_ipa_sentence  length  \
# 0                                    ['a', 'oh']       2
# 1                              ['where', 'blue']       2
# 2    ['grizzly', 'bear', 'a', 'grizzly', 'bear']       5
# 3                      ["what's", 'his', 'name']       3
# 4                                ['gigi', 'try']       2
# ..                                           ...     ...
# 495                     ['crack', 'a', 'bottle']       3
# 496                            ["it's", 'santa']       2
# 497                           ['with', 'auntie']       2
# 498                 ["what's", 'mommy', 'doing']       3
# 499                    ["what's", 'her', 'name']       3
#
#                      mcmc sentences
# 0                      knives henry
# 1                          wife jen
# 2    love doodle wanted hoop police
# 3                build basket comes
# 4                      cat's dragon
# ..                              ...
# 495          henry's another others
# 496                   friend's fits
# 497                  bakery promise
# 498              barry lessons bull
# 499              desk tortoise gail
#
# [500 rows x 32 columns]

# %%
final = new.copy()
final.to_csv('final_testing_sentences_sheets.csv')

# %%
# CODE FOR TESTING PREDICTION OF INTERPRETATIONS FOR ONE-WORD UTTERANCES

def trigrams_in_sent(sent):
    return [ngram for ngram in ngrams(sent, 3, pad_left=True, pad_right=True)]

def all_trigrams(sents):
    return [ngram for sent in sents for ngram in ngrams(sent, 3, pad_left=True, pad_right=True)]

def trigram_freq_dist(all_trigrams):
    return nltk.FreqDist(all_trigrams)

def kneser_ney_prob_dist(sents):
    trigram_list = all_trigrams(sents)
    fd = trigram_freq_dist(trigram_list)
    return KneserNeyProbDist(fd)

def kneser_ney_prob(trigram, kn_prob_dist):
    return kn_prob_dist.prob(trigram)

def process_word(word):
    new_word = word
    new_word = new_word.replace('[', '')
    new_word = new_word.replace(']', '')
    new_word = new_word.replace("'", "")
    new_word = new_word.replace(' ', '')
    new_word = new_word.replace('"', '')
    new_word = new_word.lower()
    return new_word

def create_kneser_ney_prob_dist():
    sents_for_dist = []
    with open ('complete_transcriptions.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=",")
        line_count = 0
        for row in csv_reader:
            if line_count != 0:
                sent = row[29]
                split_sent = sent.split(",")
                split_sent_list = []
                for word in split_sent:
                    processed_word = process_word(word)
                    split_sent_list.append(processed_word)
                sents_for_dist.append(split_sent_list)
            line_count += 1
    return kneser_ney_prob_dist(sents_for_dist)

def create_english_cmu_dict():
    english_cmu_dict = {}
    with open ('cmu_in_childes_22000.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=",")
        line_count = 0
        for row in csv_reader:
            if line_count != 0:
                english_cmu_dict[row[1]] = row[8]
            line_count += 1
    return english_cmu_dict

def create_english_words(english_dict):
    return list(english_dict.keys())

def init_random_sentence(english_words, num_words):
    sent = []
    for i in range(num_words):
        new_word_ind = random.randint(0, len(english_words)-1)
        new_word = english_words[new_word_ind]
        sent.append(new_word)
    return sent

def perturb_sentence(english_words, sent):
    new_sent = sent.copy()
    num_words = len(sent)
    change_ind = random.randint(0, num_words-1)
    new_word_ind = random.randint(0, len(english_words)-1)
    new_word = english_words[new_word_ind]
    new_sent[change_ind] = new_word
    return new_sent

def english_to_ipa(english_dict, sent):
    ipa_sent = []
    for word in sent:
        ipa_sent.append(english_dict[word])
    return ipa_sent

def trigram_prior_for_sent(sent, kn_prob_dist):
    trigrams = trigrams_in_sent(sent)
    num_trigrams = len(trigrams)
    trigram_priors = np.zeros(num_trigrams)
    for i in range(num_trigrams):
        trigram_priors[i] = kneser_ney_prob(trigrams[i], kn_prob_dist)
    return np.prod(trigram_priors)

def calculate_likelihood(guess, actual, match_multiplier=0.99):
    matches = 0
    no_matches = 0
    for i in range(len(actual)):
        if guess[i] == actual[i]:
            matches += 1
        else:
            no_matches += 1
    no_match_multiplier = 1-match_multiplier
    likelihood = (match_multiplier**matches)*(no_match_multiplier**no_matches)
    return likelihood

def calculate_prob(english_dict, kn_prob_dist, guess, actual, match_multiplier=0.99):
    guess_ipa = english_to_ipa(english_dict, guess)
    return trigram_prior_for_sent(guess, kn_prob_dist)*calculate_likelihood(guess_ipa, actual, match_multiplier) + 0.00001

def find_n_most_common_transcriptions(n, plausible_transcriptions):
    new_list = []
    for transcription in plausible_transcriptions:
        new_list.append(' '.join(transcription))
    counter = Counter(new_list)
    print(counter.most_common(n))

def transcribe(actual):
    plausible_transcriptions = []
    num_words = len(actual)
    english_dict = create_english_cmu_dict()
    english_words = create_english_words(english_dict)
    kn_prob_dist = create_kneser_ney_prob_dist()
    old_guess = init_random_sentence(english_words, num_words)
    for i in range(1000000):
        new_guess = perturb_sentence(english_words, old_guess)
        old_guess_prob = calculate_prob(english_dict, kn_prob_dist, old_guess, actual)
        new_guess_prob = calculate_prob(english_dict, kn_prob_dist, new_guess, actual)
        if new_guess_prob/old_guess_prob > random.random():
            old_guess = new_guess
        plausible_transcriptions.append(old_guess)
    find_n_most_common_transcriptions(10, plausible_transcriptions)

# %%
# NEW PERTURBATION ATTEMPT (ANNIE)

def trigrams_in_sent(sent):
    return [ngram for ngram in ngrams(sent, 3, pad_left=True, pad_right=True)]

def all_trigrams(sents):
    return [ngram for sent in sents for ngram in ngrams(sent, 3, pad_left=True, pad_right=True)]

def trigram_freq_dist(all_trigrams):
    return nltk.FreqDist(all_trigrams)

def kneser_ney_prob_dist(sents):
    trigram_list = all_trigrams(sents)
    fd = trigram_freq_dist(trigram_list)
    return KneserNeyProbDist(fd)

def kneser_ney_prob(trigram, kn_prob_dist):
    return kn_prob_dist.prob(trigram)

def process_word(word):
    new_word = word
    new_word = new_word.replace('[', '')
    new_word = new_word.replace(']', '')
    new_word = new_word.replace("'", "")
    new_word = new_word.replace(' ', '')
    new_word = new_word.replace('"', '')
    new_word = new_word.lower()
    return new_word

def create_kneser_ney_prob_dist():
    sents_for_dist = []
    with open ('training_sentences.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=",")
        line_count = 0
        for row in csv_reader:
            if line_count != 0:
                sent = row[29]
                split_sent = sent.split(",")
                split_sent_list = []
                for word in split_sent:
                    processed_word = process_word(word)
                    split_sent_list.append(processed_word)
                sents_for_dist.append(split_sent_list)
            line_count += 1
    return kneser_ney_prob_dist(sents_for_dist)

def create_english_cmu_dict():
    english_cmu_dict = {}
    with open ('cmu_in_childes_small.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=",")
        line_count = 0
        for row in csv_reader:
            if line_count != 0:
                english_cmu_dict[row[1]] = row[8]
            line_count += 1
    return english_cmu_dict

def create_english_words(english_dict):
    return list(english_dict.keys())

def init_random_sentence(english_words, num_words):
    sent = []
    for i in range(num_words):
        new_word_ind = random.randint(0, len(english_words)-1)
        new_word = english_words[new_word_ind]
        sent.append(new_word)
    return sent

def perturb_sentence(english_words, sent, matches_indices):
    new_sent = sent.copy()
    num_words = len(sent)
    # if matches_indices:
    #   print(matches_indices)

    if len(matches_indices) == num_words:
      return sent
    change_ind = (choice([i for i in range(0,num_words) if i not in matches_indices]))
    new_word_ind = random.randint(0, len(english_words)-1)
    new_word = english_words[new_word_ind]
    new_sent[change_ind] = new_word
    return new_sent

def english_to_ipa(english_dict, sent):
    ipa_sent = []
    for word in sent:
        ipa_sent.append(english_dict[word])
    return ipa_sent

def trigram_prior_for_sent(sent, kn_prob_dist):
    trigrams = trigrams_in_sent(sent)
    num_trigrams = len(trigrams)
    trigram_priors = np.zeros(num_trigrams)
    for i in range(num_trigrams):
        trigram_priors[i] = kneser_ney_prob(trigrams[i], kn_prob_dist)
    return np.prod(trigram_priors)

def calculate_likelihood(guess, actual, match_multiplier=0.99):
    matches = 0
    no_matches = 0
    matches_indices = []
    for i in range(len(actual)):
        if guess[i] == actual[i]:
            matches += 1
            matches_indices.append(i)
        else:
            no_matches += 1
    no_match_multiplier = 1-match_multiplier
    likelihood = (match_multiplier**matches)*(no_match_multiplier**no_matches)
    return likelihood, matches_indices

def calculate_prob(english_dict, kn_prob_dist, guess, actual, match_multiplier=0.99):
    guess_ipa = english_to_ipa(english_dict, guess)
    likelihood = calculate_likelihood(guess_ipa, actual, match_multiplier)
    prob = trigram_prior_for_sent(guess, kn_prob_dist)*likelihood[0] + 0.00001
    match_indices = likelihood[1]
    return prob, match_indices

def find_n_most_common_transcriptions(n, plausible_transcriptions):
    new_list = []
    for transcription in plausible_transcriptions:
        new_list.append(' '.join(transcription))
    counter = Counter(new_list)
    print(counter.most_common(n))

def transcribe(actual):
    plausible_transcriptions = []
    num_words = len(actual)
    english_dict = create_english_cmu_dict()
    english_words = create_english_words(english_dict)
    kn_prob_dist = create_kneser_ney_prob_dist()
    old_guess = init_random_sentence(english_words, num_words)
    matches_indices = []
    for i in range(100000):
        new_guess = perturb_sentence(english_words, old_guess, matches_indices)
        old_guess_prob = calculate_prob(english_dict, kn_prob_dist, old_guess, actual)[0]
        new_guess_prob, possible_matches_indices = calculate_prob(english_dict, kn_prob_dist, new_guess, actual)
        if new_guess_prob/old_guess_prob > random.random():
            old_guess = new_guess
            matches_indices = possible_matches_indices
        plausible_transcriptions.append(old_guess)
        # if len(old_guess) == len(matches_indices):
        #     return old_guess
    find_n_most_common_transcriptions(10, plausible_transcriptions)

def get_all_transcriptions():
    all_transcriptions = []
    with open ('testing_sentences.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=",")
        line_count = 0
        for row in csv_reader:
            if line_count != 0 and line_count < 50:
                sent = row[1]
                split_sent = sent.split(" ")
                split_sent_list = []
                for word in split_sent:
                    processed_word = process_word(word)
                    split_sent_list.append(processed_word)
                all_transcriptions.append(split_sent_list)
            line_count += 1
    return all_transcriptions

# %%
# NEW PERTURBATION ATTEMPT (DIANA)

def trigrams_in_sent(sent):
    return [ngram for ngram in ngrams(sent, 3, pad_left=True, pad_right=True)]

def all_trigrams(sents):
    return [ngram for sent in sents for ngram in ngrams(sent, 3, pad_left=True, pad_right=True)]

def trigram_freq_dist(all_trigrams):
    return nltk.FreqDist(all_trigrams)

def kneser_ney_prob_dist(sents):
    trigram_list = all_trigrams(sents)
    fd = trigram_freq_dist(trigram_list)
    return KneserNeyProbDist(fd)

def kneser_ney_prob(trigram, kn_prob_dist):
    return kn_prob_dist.prob(trigram)

def process_word(word):
    new_word = word
    new_word = new_word.replace('[', '')
    new_word = new_word.replace(']', '')
    new_word = new_word.replace("'", "")
    new_word = new_word.replace(' ', '')
    new_word = new_word.replace('"', '')
    new_word = new_word.lower()
    return new_word

def create_kneser_ney_prob_dist():
    sents_for_dist = []
    with open ('complete_transcriptions.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=",")
        line_count = 0
        for row in csv_reader:
            if line_count != 0:
                sent = row[29]
                split_sent = sent.split(",")
                split_sent_list = []
                for word in split_sent:
                    processed_word = process_word(word)
                    split_sent_list.append(processed_word)
                sents_for_dist.append(split_sent_list)
            line_count += 1
    return kneser_ney_prob_dist(sents_for_dist)

def create_english_cmu_dict():
    english_cmu_dict = {}
    with open ('cmu_in_childes_22000.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=",")
        line_count = 0
        for row in csv_reader:
            if line_count != 0:
                english_cmu_dict[row[1]] = row[8]
            line_count += 1
    return english_cmu_dict

def create_english_words():
    english_words = []
    with open ('cmu_in_childes_22000.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=",")
        line_count = 0
        for row in csv_reader:
            if line_count != 0:
                english_words.append(row[1])
            line_count += 1
    return english_words

def init_random_sentence(english_words, num_words):
    sent = []
    for i in range(num_words):
        new_word_ind = random.randint(0, len(english_words)-1)
        new_word = english_words[new_word_ind]
        sent.append(new_word)
    return sent

def determine_dict_probabilities(english_words):
    total_count = 0
    num_english_words = len(english_words)
    word_dist = np.zeros(num_english_words)
    with open ('cmu_in_childes_22000.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=",")
        line_count = 0
        for row in csv_reader:
            if line_count != 0:
                count = int(row[9])
                total_count += count
                word_dist[line_count-1] = row[9]
            line_count += 1
    divisor = np.full((num_english_words), total_count)
    return np.divide(word_dist, divisor)
    

def perturb_sentence(english_words, word_dist, sent):
    new_sent = sent.copy()
    num_words = len(sent)
    change_ind = random.randint(0, num_words-1)
    #new_word_ind = random.randint(0, len(english_words)-1)
    #new_word = english_words[new_word_ind]
    rng = default_rng()
    new_word_ind = rng.choice(len(english_words), size=1, p=word_dist)
    new_word = english_words[int(new_word_ind)]
    new_sent[change_ind] = new_word
    return new_sent

def english_to_ipa(english_dict, sent):
    ipa_sent = []
    for word in sent:
        ipa_sent.append(english_dict[word])
    return ipa_sent

def trigram_prior_for_sent(sent, kn_prob_dist):
    trigrams = trigrams_in_sent(sent)
    num_trigrams = len(trigrams)
    trigram_priors = np.zeros(num_trigrams)
    for i in range(num_trigrams):
        trigram_priors[i] = kneser_ney_prob(trigrams[i], kn_prob_dist)
    return np.prod(trigram_priors)

def calculate_likelihood(guess, actual, match_multiplier=0.99):
    matches = 0
    no_matches = 0
    for i in range(len(actual)):
        if guess[i] == actual[i]:
            matches += 1
        else:
            no_matches += 1
    no_match_multiplier = 1-match_multiplier
    likelihood = (match_multiplier**matches)*(no_match_multiplier**no_matches)
    return likelihood

def calculate_prob(english_dict, kn_prob_dist, guess, actual, match_multiplier=0.99):
    guess_ipa = english_to_ipa(english_dict, guess)
    return trigram_prior_for_sent(guess, kn_prob_dist)*calculate_likelihood(guess_ipa, actual, match_multiplier) + 0.00001

def find_n_most_common_transcriptions(n, plausible_transcriptions):
    new_list = []
    for transcription in plausible_transcriptions:
        new_list.append(' '.join(transcription))
    counter = Counter(new_list)
    print(counter.most_common(n))

def transcribe(actual):
    plausible_transcriptions = []
    num_words = len(actual)
    english_dict = create_english_cmu_dict()
    english_words = create_english_words()
    word_dist = determine_dict_probabilities(english_words)
    kn_prob_dist = create_kneser_ney_prob_dist()
    old_guess = init_random_sentence(english_words, num_words)
    for i in range(1000000):
        new_guess = perturb_sentence(english_words, word_dist, old_guess)
        old_guess_prob = calculate_prob(english_dict, kn_prob_dist, old_guess, actual)
        new_guess_prob = calculate_prob(english_dict, kn_prob_dist, new_guess, actual)
        if new_guess_prob/old_guess_prob > random.random():
            old_guess = new_guess
        plausible_transcriptions.append(old_guess)
    find_n_most_common_transcriptions(10, plausible_transcriptions)

def get_all_transcriptions():
    all_transcriptions = []
    with open ('complete_transcriptions.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=",")
        line_count = 0
        for row in csv_reader:
            if line_count != 0 and line_count < 50:
                sent = row[1]
                split_sent = sent.split(" ")
                split_sent_list = []
                for word in split_sent:
                    processed_word = process_word(word)
                    split_sent_list.append(processed_word)
                all_transcriptions.append(split_sent_list)
            line_count += 1
    return all_transcriptions
